# %%
f = open("small_input.txt","r")
hours = []
stool = []
bench = []
l2 = []
cust = []
for i in f.readlines():
    l1 = i.split("\n")[0].split(' ')
#     print(len(i))
    if len(i) == 10 or len(i) ==11:
        l1.remove('')
        l1.remove('')
        hours.append(int(l1[0])),stool.append(int(l1[1])),bench.append(int(l1[2])) 
    else:
        for i in i.split('\n')[0].split(' '):
            print(i)
#             cust.append(i)
#         l2.append(cust)
#         cust.append(i.split('\n')[0])
        print(cust)
print(hours,'\n========================\n',stool,"\n========================\n",bench)
f = open("output.txt","w")
f.write(hours,'\n========================\n',stool,"\n========================\n",bench)
# Out:
# 121
#
# 55
#
# 133
#
# 105
#
# 112
#
# 113
#
# 145
#
# 138
#
# 81
# []
# 173
#
# 58
#
# 124
#
# 113
#
# 72
#
# 142
#
# 99
#
# 140
#
# 85
# []
# 146
#
# 81
#
# 113
#
# 78
#
# 93
#
# 103
#
# 128
#
# 102
#
# 145
# []
# 132
#
# 95
#
# 133
#
# 144
#
# 77
#
# 130
#
# 81
#
# 137
#
# 110
# []
# 97
#
# 80
#
# 78
#
# 110
#
# 149
#
# 139
#
# 141
#
# 103
#
# 72
# []
# 178
#
# 95
#
# 85
#
# 132
#
# 127
#
# 102
#
# 144
#
# 86
#
# 105
# []
# 102
#
# 70
#
# 93
#
# 108
#
# 96
#
# 129
#
# 144
#
# 106
#
# 121
# []
# 174
#
# 75
#
# 145
#
# 121
#
# 126
#
# 113
#
# 123
#
# 140
#
# 127
# []
# 76
#
# 72
#
# 70
#
# 110
#
# 94
#
# 90
#
# 101
#
# 124
#
# 96
# []
# 149
#
# 81
#
# 85
#
# 86
#
# 138
#
# 98
#
# 94
#
# 119
#
# 120
# []
# 154
#
# 88
#
# 106
#
# 144
#
# 96
#
# 90
#
# 100
#
# 141
#
# 135
# []
# 110
#
# 93
#
# 100
#
# 83
#
# 128
#
# 125
#
# 148
#
# 94
#
# 100
# []
# 148
#
# 87
#
# 150
#
# 84
#
# 146
#
# 114
#
# 138
#
# 115
#
# 125
# []
# 114
#
# 57
#
# 148
#
# 101
#
# 91
#
# 104
#
# 98
#
# 93
#
# 130
# ...
